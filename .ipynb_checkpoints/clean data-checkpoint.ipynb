# 16      Hard      2nd Round        3     Istomin D.  ...  1.90   1.80  1.91
# 17      Hard      2nd Round        3    Harrison R.  ...  1.30   3.20  1.36
# 18      Hard      2nd Round        3      Edmund K.  ...  2.00   1.72  2.10
# 19      Hard      2nd Round        3    Dimitrov G.  ...  1.16   4.60  1.17
# 20      Hard  Quarterfinals        3   De Minaur A.  ...  1.65   2.10  1.73
# 21      Hard  Quarterfinals        3     Kyrgios N.  ...  1.40   2.75  1.44
# 22      Hard  Quarterfinals        3    Harrison R.  ...  1.80   1.90  1.91
# 23      Hard  Quarterfinals        3    Dimitrov G.  ...  1.33   3.05  1.36
# 24      Hard     Semifinals        3    Harrison R.  ...  1.60   2.20  1.73
# 25      Hard     Semifinals        3     Kyrgios N.  ...  2.00   1.72  2.00
# 26      Hard      The Final        3     Kyrgios N.  ...  1.19   4.20  1.22
# 27      Hard      1st Round        3      Rublev A.  ...  1.47   2.50  1.57
# 28      Hard      1st Round        3    Verdasco F.  ...  1.37   2.85  1.44
# 29      Hard      1st Round        3       Thiem D.  ...  1.19   4.20  1.20
# ...      ...            ...      ...            ...  ...   ...    ...   ...
# 2607    Hard      3rd Round        3       Cilic M.  ...  1.47   2.85   NaN
# 2608    Hard      3rd Round        3   Khachanov K.  ...  1.53   2.65   NaN
# 2609    Hard      3rd Round        3    Djokovic N.  ...  1.04  15.00   NaN
# 2610    Hard      3rd Round        3      Zverev A.  ...  1.28   4.00   NaN
# 2611    Hard      3rd Round        3        Sock J.  ...  1.38   3.00   NaN
# 2612    Hard      3rd Round        3       Thiem D.  ...  1.85   2.05   NaN
# 2613    Hard      3rd Round        3     Federer R.  ...  1.15   6.25   NaN
# 2614    Hard      3rd Round        3   Nishikori K.  ...  1.73   2.20   NaN
# 2615    Hard  Quarterfinals        3   Khachanov K.  ...  2.95   1.45   NaN
# 2616    Hard  Quarterfinals        3       Thiem D.  ...  1.32   3.70   NaN
# 2617    Hard  Quarterfinals        3    Djokovic N.  ...  1.17   5.75   NaN
# 2618    Hard  Quarterfinals        3     Federer R.  ...  1.47   2.85   NaN
# 2619    Hard     Semifinals        3   Khachanov K.  ...  1.95   1.95   NaN
# 2620    Hard     Semifinals        3    Djokovic N.  ...  1.38   3.00   NaN
# 2621    Hard      The Final        3   Khachanov K.  ...  5.25   1.19   NaN
# 2622    Hard    Round Robin        3    Anderson K.  ...  1.83   2.10   NaN
# 2623    Hard    Round Robin        3   Nishikori K.  ...  4.20   1.28   NaN
# 2624    Hard    Round Robin        3      Zverev A.  ...  1.83   2.10   NaN
# 2625    Hard    Round Robin        3    Djokovic N.  ...  1.13   7.50   NaN
# 2626    Hard    Round Robin        3    Anderson K.  ...  2.30   1.70   NaN
# 2627    Hard    Round Robin        3     Federer R.  ...  1.37   3.45   NaN
# 2628    Hard    Round Robin        3    Djokovic N.  ...  1.17   6.00   NaN
# 2629    Hard    Round Robin        3       Cilic M.  ...  1.50   2.85   NaN
# 2612   NaN  1.83   2.11  1.86   2.15  1.80   2.03
# 2613   NaN  1.15   6.61  1.15   7.25  1.13   6.00
# 2614   NaN  1.75   2.24  1.76   2.25  1.72   2.14
# 2615   NaN  2.88   1.49  2.95   1.49  2.80   1.45
# 2616   NaN  1.29   4.05  1.45   4.05  1.31   3.55
# 2617   NaN  1.19   5.61  1.19   6.00  1.15   5.56
# 2618   NaN  1.47   2.93  1.50   2.93  1.46   2.79
# 2619   NaN  1.98   1.94  2.03   2.00  1.92   1.91
# 2620   NaN  1.43   3.12  1.47   3.25  1.40   3.02
# 2621   NaN  5.50   1.19  5.50   1.25  5.04   1.18
# 2622   NaN  1.81   2.12  1.90   2.12  1.80   2.03
# 2623   NaN  4.05   1.29  4.20   1.30  3.97   1.26
# 2624   NaN  1.85   2.06  1.87   2.13  1.80   2.04
# 2625   NaN  1.12   7.50  1.13   7.50  1.11   6.92
# 2626   NaN  2.24   1.73  2.35   1.74  2.23   1.66
# 2627   NaN  1.37   3.42  1.40   3.65  1.35   3.28
# 2628   NaN  1.18   5.73  1.20   6.00  1.16   5.32
# 2629   NaN  1.49   2.82  1.50   2.95  1.47   2.74
# 2630   NaN  2.57   1.57  2.74   1.57  2.59   1.52
# 2631   NaN  1.37   3.38  1.44   3.40  1.38   3.12
# 2632   NaN  1.40   3.22  1.44   3.40  1.38   3.14
# 2633   NaN  1.20   5.23  1.22   6.03  1.17   5.14
# 2634   NaN  3.24   1.41  3.40   1.45  3.14   1.38
# 2635   NaN  1.12   7.72  1.15   7.72  1.12   6.52
# 2636   NaN  6.36   1.16  6.36   1.22  5.69   1.15
#
# [2637 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
#        'Lsets', 'Comment', 'B365W', 'B365L', 'EXW', 'EXL', 'LBW', 'LBL', 'PSW',
#        'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL'],
#       dtype='object')

# %%
sort_list = [random.choice([True,False]) for i in range(len(df))]
inverse_list = [not i for i in sort_list]

# %%
df['Fav'] = [winner if condition  else loser for winner, loser, condition in zip(df.Winner, df.Loser, df.WPts > df.LPts) ]
df['nFav']= [loser if condition  else winner for winner, loser, condition in zip(df.Winner, df.Loser, df.WPts > df.LPts) ]

df['P1'] = [winner if condition  else loser for winner, loser, condition in zip(df.Winner, df.Loser, sort_list) ]
df['P2'] = [winner if condition  else loser for winner, loser, condition in zip(df.Winner, df.Loser, inverse_list) ]


def sort_by_player(df, p1_stat, p2_stat, w_stat, l_stat, sort_list ):
    inverse_list = [not i for i in sort_list]
    df[p1_stat] = [winner if condition  else loser for winner, loser, condition in zip(df[w_stat], df[l_stat], sort_list)]
    df[p2_stat] = [winner if condition  else loser for winner, loser, condition in zip(df[w_stat], df[l_stat], inverse_list )]

# df['P1Rank'] = [winner if condition  else loser for winner, loser, condition in zip(df.WRank, df.LRank, sort_list)]
# df['P2Rank'] = [winner if condition  else loser for winner, loser, condition in zip(df.WRank, df.LRank, inverse_list)]


columns_by_winner = ['WRank', 'LRank', 'WPts', 'LPts',
       'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
       'Lsets', 'B365W', 'B365L', 'EXW', 'EXL', 'LBW', 'LBL', 'PSW',
       'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL', 'Fav', 'nFav', 'P1', 'P2',
       'P1Rank', 'P2Rank', 'P1Pts', 'P2Pts', 'P11', 'P21', 'P12', 'P22', 'P13',
       'P23', 'P14', 'P24', 'P15', 'P25', 'P1sets', 'P2sets', 'B365P1',
       'B365P2', 'EXP1', 'EXP2', 'P2BP1', 'P2BP2', 'PSP1', 'PSP2']
columns_by_player = [re.sub('L', 'P2', j) for j in [re.sub('W', 'P1', i) for i in columns_by_winner]]



# sort_by_player(df,'P1Pts', 'P2Pts', 'WPts', 'LPts' sort_list)
# sort_by_player(df,'P11', 'P21', 'W1', 'L1' sort_list)
# sort_by_player(df,'P12', 'P22', 'W2', 'L2' sort_list)

cw = [columns_by_winner[i:i+2] for i in range(0,len(columns_by_winner),2)]
cp = [columns_by_player[i:i+2] for i in range(0,len(columns_by_winner),2)]

for i in range(len(cw)): 
    cp[i].extend(cw[i])
    sort_by_player(df, *cp[i] ,sort_list)

# %%
df['PtsDelta'] = df.P1Pts - df.P2Pts

# %%
#clusters taken from 310774506_Tennis_betting_Can_statistics_beat_bookmakers

def intervals(delta):
    if 0 < abs(delta) < 560:
        return 1*np.sign(delta)
    elif 560 <= abs(delta) < 920:
        return 2*np.sign(delta)
    elif 920 <= abs(delta) < 1460:
        return 3*np.sign(delta)
    elif 1460 <= abs(delta) < 2000:
        return 4*np.sign(delta)
    elif 2000 <= abs(delta):
        return 5*np.sign(delta)
    else:return None

df['IntervalDelta'] = df.PtsDelta.apply(intervals)

# %%
players = pd.read_csv('tennis_atp/atp_players.csv', encoding='iso-8859-1', names=['id', 'first_name', 'surname', 'hand', 'points','country'])

# %%
# df = pd.read_excel('tennis_data/2018.xlsx')

all_atp_data_paths = []
for i in range(2000,2018): all_atp_data_paths.append('tennis_atp/atp_matches_{year}.csv'.format(year=i))


frames = [pd.read_csv(i) for i in all_atp_data_paths]

# frames
atp = pd.concat(frames, sort=False)




atp.tourney_date = pd.to_datetime(atp.tourney_date, format='%Y%m%d')

# %%
def get_p_bday(player, theta=80):
    accuracy = 90
    while accuracy > theta:
        for i in atp.winner_name:
            if fuzz.token_sort_ratio(player, i)>accuracy:
                info = (atp[['winner_age', 'tourney_date','winner_name']][atp.winner_name==i]).iloc[0]
                age = info[0]
                year = info[1]
                print(info)
                return year - relativedelta(years=int(age), days=int(((age-int(age))*365.24)))
                break
        accuracy -=5 
    return np.nan

def get_pbday(pl_id):
    try:
        info = atp[['winner_age', 'tourney_date']][atp.winner_id == pl_id].iloc[0]
        age = info[0]
        year = info[1]
        return year - relativedelta(years=int(age), days=int(((age-int(age))*365.24)))
    except IndexError as e:
        try:
            info = atp[['loser_age', 'tourney_date']][atp.loser_id == pl_id].iloc[0]
            age = info[0]
            year = info[1]
            return year - relativedelta(years=int(age), days=int(((age-int(age))*365.24)))
        except IndexError as ee:
            return np.nan

        
# df['W_bday']= df.Winner.apply(get_p_bday)

# %%
# players['birthday'] = players.id.apply(get_pbday)
# players.birthday.value_counts()

def get_wbday(info):
    try: 
        age = info['winner_age']
        year = info['tourney_date']
        return year - relativedelta(years=int(age), days=int(((age-int(age))*365.24)))
    except ValueError as e: return np.nan

def get_lbday(info):
    try: 
        age = info['loser_age']
        year = info['tourney_date']
        return year - relativedelta(years=int(age), days=int(((age-int(age))*365.24)))
    except ValueError as e: return np.nan

atp['winner_birthday'] = atp.apply(get_wbday, axis=1)
atp['loser_birthday'] = atp.apply(get_lbday, axis=1)

# %%
atp1 = pd.concat([atp.winner_id,atp.winner_birthday], axis=1).rename(columns={'winner_id':'id', 'winner_birthday':'birthday'})

atp2 = pd.concat([atp.loser_id,atp.loser_birthday], axis=1).rename(columns={'loser_id':'id', 'loser_birthday':'birthday'})

players_only = atp1.append(atp2)

players_only.drop_duplicates(inplace=True, subset='id')

print(len(players), len(players_only))
# Out:
# 53319 2152

# %%
def calculate_age(born, today):
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

# %%
players_ = pd.merge(players_only, players, on='id')

# %%
len(players_)
# Out:
# 2151

# %%
wnames
# Out:
#        winner_surname  winner_id winner_birthday winner_country
# 0              Dupuis   102179.0      1973-02-24            FRA
# 1            Gonzalez   103602.0      1980-07-29            CHI
# 2          Srichaphan   103387.0      1979-06-15            THA
# 3           Siemerink   101733.0      1970-04-14            NED
# 4         Stoltenberg   101727.0      1970-04-04            AUS
# 5               Vanek   103181.0      1978-04-24            CZE
# 6           Rodriguez   101675.0      1969-12-18            ARG
# 7           Goldstein   102834.0      1976-08-04            USA
# 8               Massu   103454.0      1979-10-11            CHI
# 9             Kroslak   102466.0      1974-10-17            SVK
# 10            Russell   103188.0      1978-05-01            USA
# 11              Pozzi   101150.0      1965-06-17            ITA
# 12              Sabau   103009.0      1977-06-18            ROU
# 13           Hantschk   103082.0      1977-11-19            GER
# 14            Malisse   103598.0      1980-07-19            BEL
# 15            Delgado   102887.0      1976-11-14            PAR
# 16             Agassi   101736.0      1970-04-29            USA
# 17             Tabara   103420.0      1979-08-12            CZE
# 18            Tarango   101543.0      1968-11-20            USA
# 19            Larsson   101723.0      1970-03-25            SWE
# 20           Sargsian   102227.0      1973-06-03            ARM
# 21           Woodruff   102162.0      1973-01-02            USA
# 22         Woodbridge   101889.0      1971-04-02            AUS
# 23             Alonso   103031.0      1977-08-02            ESP
# 24              Chang   102021.0      1972-02-23            USA
# 25               Ilie   102776.0      1976-04-18            AUS
# 26               Huet   101902.0      1971-04-26            FRA
# 27             Koubek   102905.0      1977-01-02            AUT
# 28         Kafelnikov   102338.0      1974-02-19            RUS
# 29              Vacek   101888.0      1971-04-02            CZE
# ...               ...        ...             ...            ...
# 2121      Blancaneaux   144972.0      1998-08-08            FRA
# 2122         Safranek   106324.0      1994-05-20            CZE
# 2123           Kypson   200516.0      1999-10-29            USA
# 2124          Aragone   111574.0      1995-06-28            USA
# 2125          Tyurnev   126185.0      1997-04-09            RUS
# 2126             Kuhn   200095.0      2000-03-21            GER
# 2127        Takahashi   126208.0             NaT            JPN
# 2128        Safiullin   126128.0      1997-08-08            RUS
# 2129            Hardt   200572.0      2000-09-25            DOM
# 2130           Merino   122635.0      1992-09-05            PER
# 2131              Lee   117353.0      1998-06-02            KOR
# 2132             Kwon   126952.0      1997-12-06            KOR
# 2133            Oliel   200075.0      2000-01-09            ISR
# 2134        Cukierman   131951.0      1995-07-13            ISR
# 2135        Mashtakov   200125.0      1999-03-22            UKR
# 2136      Biloborodko   207277.0      2001-05-11            UKR
# 2137            Major   132040.0      1996-03-07            BAH
# 2138           Newman   106180.0      1993-05-10            USA
# 2139             Lunn   132028.0      1991-06-22            BAH
# 2140   Foster Estwick   207759.0      1997-08-31            BAR
# 2141          Susanto   200045.0      1997-05-27            INA
# 2142               Li   124023.0      1997-04-01            HKG
# 2143           Siimar   144940.0      1998-02-07            EST
# 2144       Ruusuvuori   200325.0      1999-04-06            FIN
# 2145  Niklas Salminen   126609.0      1997-03-09            FIN
# 2146  Andriamasilalao   145003.0      1997-06-27            MAD
# 2147           Zitnik   105798.0      1991-07-06            SLO
# 2148           Dougaz   144826.0             NaT            TUN
# 2149       Efstathiou   144949.0      1999-03-06            CYP
# 2150         Campbell   123315.0      1971-01-21            AUS
#
# [2151 rows x 4 columns]

# %%
df['loser_surname']= df.Loser.str[:-3]

df['winner_surname']= df.Winner.str[:-3]

# %% [raw]
# df.head()

# %%
players['initial'] = play
# Out:
#            id       first_name            surname hand      points country
# 0      100001          Gardnar             Mulloy    R  19131122.0     USA
# 1      100002           Pancho             Segura    R  19210620.0     ECU
# 2      100003            Frank            Sedgman    R  19271002.0     AUS
# 3      100004         Giuseppe              Merlo    R  19271011.0     ITA
# 4      100005   Richard Pancho           Gonzales    R  19280509.0     USA
# 5      100006            Grant             Golden    R  19290821.0     USA
# 6      100007              Abe              Segal    L  19301023.0     RSA
# 7      100008             Kurt            Nielsen    R  19301119.0     DEN
# 8      100009           Istvan             Gulyas    R  19311014.0     HUN
# 9      100010             Luis              Ayala    R  19320918.0     CHI
# 10     100011           Torben             Ulrich    L  19321004.0     DEN
# 11     100012           Nicola        Pietrangeli    R  19330911.0     ITA
# 12     100013            Neale             Fraser    L  19331003.0     AUS
# 13     100014           Trevor            Fancutt    R  19340714.0     RSA
# 14     100015            Sammy          Giammalva    R  19340801.0     USA
# 15     100016              Ken           Rosewall    R  19341102.0     AUS
# 16     100017              Mal           Anderson    R  19350303.0     AUS
# 17     100018            Barry             Mackay    R  19350831.0     USA
# 18     100019          Wieslaw           Gasiorek    R  19360113.0     POL
# 19     100020        Alejandro             Olmedo    R  19360324.0     PER
# 20     100021           Ashley             Cooper    R  19360915.0     AUS
# 21     100022              Roy            Emerson    R  19361103.0     AUS
# 22     100023       Ramanathan           Krishnan    R  19370411.0     IND
# 23     100024         Jan Eric          Lundquist    R  19370414.0     SWE
# 24     100025            Barry     Phillips Moore    R  19370709.0     AUS
# 25     100026           Andres             Gimeno    R  19370803.0     ESP
# 26     100027             Gene              Scott    R  19371228.0     USA
# 27     100028           Manuel            Santana    R  19380510.0     ESP
# 28     100029              Rod              Laver    L  19380809.0     AUS
# 29     100030             Fred             Stolle    R  19381008.0     AUS
# ...       ...              ...                ...  ...         ...     ...
# 53289  208255          Lorenzo          Vatteroni    R  20000927.0     ITA
# 53290  208256        Alexander             Grekul    U  20010326.0     UKR
# 53291  208257         Fabrizio           Andaloro    U  20010131.0     ITA
# 53292  208258           Daniel               Khin    U  20000407.0     HUN
# 53293  208259       Viacheslav              Yulik    R  20000906.0     RUS
# 53294  208260          Zachary             Svajda    U  20021129.0     USA
# 53295  208261          Brandon       Stringfellow    U  19990825.0     USA
# 53296  208262    Alejo Lorenzo    Lingua Lavallen    L  20010309.0     ARG
# 53297  208263         Giuseppe             Sicolo    U  19960514.0     ITA
# 53298  208264           Carles          Hernandez    U  20010425.0     ESP
# 53299  208265           Pierre             Delage    U  20010122.0     FRA
# 53300  208266        Gianmarco           Amatiste    U  20000509.0     ESP
# 53301  208267            Oscar          Weightman    U  20011119.0     GBR
# 53302  208268           Joseph  Newman Billington    L  19991019.0     GBR
# 53303  208269            Felix               Gill    U  20020601.0     GBR
# 53304  208270           Razvan             Aghion    U  20031211.0     ROU
# 53305  208271    Robert Damian              Savin    U  20011128.0     ROU
# 53306  208272     Lucas Carlos    Ribas Crichigno    U  20000108.0     PAR
# 53307  208273  Agustin Eduardo    Cuellar Lorberg    U  20030424.0     BOL
# 53308  208274          Nicolas     Fernandez Vina    U  19981012.0     ARG
# 53309  208275           Blaine             Boyden    U         NaN     USA
# 53310  208276            Obrad          Markovski    U  20001101.0     MKD
# 53311  208277            Taiyo           Yamanaka    U  20010905.0     JPN
# 53312  208278         Shintaro          Mochizuki    U  20030602.0     JPN
# 53313  208279        Alejandro         Moro Canas    U  20001207.0     ESP
# 53314  208280           Daniel             Martin    U  20010521.0     GBR
# 53315  208281            Lamar            Bartley    U  19961216.0     GBR
# 53316  208282              Jim             Walder    U  20000731.0     GER
# 53317  208283            Andre             Rodeia    U  20010926.0     POR
# 53318  208284           Hunter             Tubert    U         NaN     USA
#
# [53319 rows x 6 columns]

# %%
wnames = players_[['surname','id','birthday','country',]].rename(columns={'surname':'winner_surname','id':'winner_id', 'birthday': 'winner_birthday', 'country':'winner_country'})

# %%
# df = pd.merge(df, wnames, on='winner_surname', how='inner',)
len(df)
# Out:
# 3115

# %%
df['winner_initial'] = df.Winner.str[-2:-1]
df['loser_initial'] = df.Loser.str[-2:-1]
