# %%
import numpy as np
import pandas as pd
import random
import re
# %matplotlib inline
from itertools import chain
import glob
import os
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
import datetime
import dateutil
from dateutil.relativedelta import relativedelta
from datetime import date
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix,log_loss
from sklearn.metrics import r2_score, balanced_accuracy_score, explained_variance_score

# %%
path = 'tennis_data/'

# df = pd.read_excel('tennis_data/2018.xlsx')

all_data_paths = glob.glob(os.path.join(path,'*.xlsx'))

frames = [pd.read_excel(i) for i in all_data_paths]

df = pd.concat(frames, sort=False)
df.reset_index(drop=True)

df['loser_surname']= df.Loser.str[:-3]
df['winner_surname']= df.Winner.str[:-3]
df['winner_initial'] = df.Winner.str[-2:-1]
df['loser_initial'] = df.Loser.str[-2:-1]


#
players = pd.read_csv('tennis_atp/atp_players.csv',encoding='iso-8859-1', names=['id', 'first_name', 'surname', 'hand', 'points','country'])

all_atp_data_paths = []
for i in range(2000,2018): all_atp_data_paths.append('tennis_atp/atp_matches_{year}.csv'.format(year=i))


frames = [pd.read_csv(i) for i in all_atp_data_paths]

# frames
atp = pd.concat(frames, sort=False)

atp.tourney_date = pd.to_datetime(atp.tourney_date, format='%Y%m%d')


len(df)
# Out:
# 16278

# %%
df.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
#        'Lsets', 'Comment', 'B365W', 'B365L', 'EXW', 'EXL', 'LBW', 'LBL', 'PSW',
#        'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL', 'SJW', 'SJL', 'loser_surname',
#        'winner_surname', 'winner_initial', 'loser_initial'],
#       dtype='object')

# %%
# create player 1 and 2 columns and sort winner/loser stats into p1/p2 stats

sort_list = [random.choice([True,False]) for i in range(len(df))]
inverse_list = [not i for i in sort_list]

df['P1'] = [winner if condition  else loser for winner, loser, condition in zip(df.Winner, df.Loser, sort_list) ]
df['P2'] = [winner if condition  else loser for winner, loser, condition in zip(df.Winner, df.Loser, inverse_list) ]


def sort_by_player(df, p1_stat, p2_stat, w_stat, l_stat, sort_list ):
    #creates player 1 and player 2 stats columsn from winner stat and loser stat using a boolean list for map
    inverse_list = [not i for i in sort_list]
    df[p1_stat] = [winner if condition  else loser for winner, loser, condition in zip(df[w_stat], df[l_stat], sort_list)]
    df[p2_stat] = [winner if condition  else loser for winner, loser, condition in zip(df[w_stat], df[l_stat], inverse_list )]

# df['P1Rank'] = [winner if condition  else loser for winner, loser, condition in zip(df.WRank, df.LRank, sort_list)]
# df['P2Rank'] = [winner if condition  else loser for winner, loser, condition in zip(df.WRank, df.LRank, inverse_list)]


columns_by_winner = ['WRank', 'LRank', 'WPts', 'LPts',
       'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
       'Lsets', 'B365W', 'B365L', 'EXW', 'EXL', 'LBW', 'LBL', 'PSW',
       'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL']
columns_by_player = [re.sub('L', 'P2', j) for j in [re.sub('W', 'P1', i) for i in columns_by_winner]]


cw = [columns_by_winner[i:i+2] for i in range(0,len(columns_by_winner),2)]
cp = [columns_by_player[i:i+2] for i in range(0,len(columns_by_winner),2)]


for i in range(len(cw)): 
    cp[i].extend(cw[i])
    sort_by_player(df, *cp[i] ,sort_list)

# %%
df[['Winner', 'Loser', 'WRank', 'LRank','P1','P2', 'P1Rank', 'P2Rank']].head()
# Out:
#         Winner        Loser  WRank  LRank           P1           P2  P1Rank  \
# 0  Thompson J.      Ymer E.   79.0  160.0      Ymer E.  Thompson J.   160.0
# 1     Mahut N.    Robert S.   39.0   54.0    Robert S.     Mahut N.    54.0
# 2    Ferrer D.     Tomic B.   21.0   26.0    Ferrer D.     Tomic B.    21.0
# 3    Edmund K.  Escobedo E.   45.0  141.0    Edmund K.  Escobedo E.    45.0
# 4  Dimitrov G.   Johnson S.   17.0   33.0  Dimitrov G.   Johnson S.    17.0
#
#    P2Rank
# 0    79.0
# 1    39.0
# 2    26.0
# 3   141.0
# 4    33.0

# %%
#clusters taken from 310774506_Tennis_betting_Can_statistics_beat_bookmakers

def intervals(delta):
    if 0 < abs(delta) < 560:
        return 1*np.sign(delta)
    elif 560 <= abs(delta) < 920:
        return 2*np.sign(delta)
    elif 920 <= abs(delta) < 1460:
        return 3*np.sign(delta)
    elif 1460 <= abs(delta) < 2000:
        return 4*np.sign(delta)
    elif 2000 <= abs(delta):
        return 5*np.sign(delta)
    else:return None

df['PtsDelta'] = df.P1Pts - df.P2Pts

df['IntervalDelta'] = df.PtsDelta.apply(intervals)

# %%
df
# Out:
#       ATP  Location              Tournament       Date        Series    Court  \
# 0       1  Brisbane  Brisbane International 2017-01-01        ATP250  Outdoor
# 1       1  Brisbane  Brisbane International 2017-01-02        ATP250  Outdoor
# 2       1  Brisbane  Brisbane International 2017-01-02        ATP250  Outdoor
# 3       1  Brisbane  Brisbane International 2017-01-02        ATP250  Outdoor
# 4       1  Brisbane  Brisbane International 2017-01-02        ATP250  Outdoor
# 5       1  Brisbane  Brisbane International 2017-01-03        ATP250  Outdoor
# 6       1  Brisbane  Brisbane International 2017-01-03        ATP250  Outdoor
# 7       1  Brisbane  Brisbane International 2017-01-03        ATP250  Outdoor
# 8       1  Brisbane  Brisbane International 2017-01-03        ATP250  Outdoor
# 9       1  Brisbane  Brisbane International 2017-01-03        ATP250  Outdoor
# 10      1  Brisbane  Brisbane International 2017-01-03        ATP250  Outdoor
# 11      1  Brisbane  Brisbane International 2017-01-03        ATP250  Outdoor
# 12      1  Brisbane  Brisbane International 2017-01-04        ATP250  Outdoor
# 13      1  Brisbane  Brisbane International 2017-01-04        ATP250  Outdoor
# 14      1  Brisbane  Brisbane International 2017-01-04        ATP250  Outdoor
# 15      1  Brisbane  Brisbane International 2017-01-04        ATP250  Outdoor
# 16      1  Brisbane  Brisbane International 2017-01-05        ATP250  Outdoor
# 17      1  Brisbane  Brisbane International 2017-01-05        ATP250  Outdoor
# 18      1  Brisbane  Brisbane International 2017-01-05        ATP250  Outdoor
# 19      1  Brisbane  Brisbane International 2017-01-05        ATP250  Outdoor
# 20      1  Brisbane  Brisbane International 2017-01-06        ATP250  Outdoor
# 21      1  Brisbane  Brisbane International 2017-01-06        ATP250  Outdoor
# 22      1  Brisbane  Brisbane International 2017-01-06        ATP250  Outdoor
# 23      1  Brisbane  Brisbane International 2017-01-06        ATP250  Outdoor
# 24      1  Brisbane  Brisbane International 2017-01-07        ATP250  Outdoor
# 25      1  Brisbane  Brisbane International 2017-01-07        ATP250  Outdoor
# 26      1  Brisbane  Brisbane International 2017-01-08        ATP250  Outdoor
# 27      2   Chennai            Chennai Open 2017-01-02        ATP250  Outdoor
# 28      2   Chennai            Chennai Open 2017-01-02        ATP250  Outdoor
# 29      2   Chennai            Chennai Open 2017-01-02        ATP250  Outdoor
# ...   ...       ...                     ...        ...           ...      ...
# 2607   66     Paris     BNP Paribas Masters 2018-11-01  Masters 1000   Indoor
# 2608   66     Paris     BNP Paribas Masters 2018-11-01  Masters 1000   Indoor
# 2609   66     Paris     BNP Paribas Masters 2018-11-01  Masters 1000   Indoor
# 2610   66     Paris     BNP Paribas Masters 2018-11-01  Masters 1000   Indoor
# 2611   66     Paris     BNP Paribas Masters 2018-11-01  Masters 1000   Indoor
# 2612   66     Paris     BNP Paribas Masters 2018-11-01  Masters 1000   Indoor
# 2613   66     Paris     BNP Paribas Masters 2018-11-01  Masters 1000   Indoor
# 2614   66     Paris     BNP Paribas Masters 2018-11-01  Masters 1000   Indoor
# 2615   66     Paris     BNP Paribas Masters 2018-11-02  Masters 1000   Indoor
# 2616   66     Paris     BNP Paribas Masters 2018-11-02  Masters 1000   Indoor
# 2617   66     Paris     BNP Paribas Masters 2018-11-02  Masters 1000   Indoor
# 2618   66     Paris     BNP Paribas Masters 2018-11-02  Masters 1000   Indoor
# 2619   66     Paris     BNP Paribas Masters 2018-11-03  Masters 1000   Indoor
# 2620   66     Paris     BNP Paribas Masters 2018-11-03  Masters 1000   Indoor
# 2621   66     Paris     BNP Paribas Masters 2018-11-04  Masters 1000   Indoor
# 2622   67    London             Masters Cup 2018-11-11   Masters Cup   Indoor
# 2623   67    London             Masters Cup 2018-11-11   Masters Cup   Indoor
# 2624   67    London             Masters Cup 2018-11-12   Masters Cup   Indoor
# 2625   67    London             Masters Cup 2018-11-12   Masters Cup   Indoor
# 2626   67    London             Masters Cup 2018-11-13   Masters Cup   Indoor
# 2627   67    London             Masters Cup 2018-11-13   Masters Cup   Indoor
# 2628   67    London             Masters Cup 2018-11-14   Masters Cup   Indoor
# 2629   67    London             Masters Cup 2018-11-14   Masters Cup   Indoor
# 2630   67    London             Masters Cup 2018-11-15   Masters Cup   Indoor
# 2631   67    London             Masters Cup 2018-11-15   Masters Cup   Indoor
# 2632   67    London             Masters Cup 2018-11-16   Masters Cup   Indoor
# 2633   67    London             Masters Cup 2018-11-16   Masters Cup   Indoor
# 2634   67    London             Masters Cup 2018-11-17   Masters Cup   Indoor
# 2635   67    London             Masters Cup 2018-11-17   Masters Cup   Indoor
# 2636   67    London             Masters Cup 2018-11-18   Masters Cup   Indoor
#
#      Surface          Round  Best of          Winner  ... P2BP1  P2BP2  PSP1  \
# 0       Hard      1st Round        3     Thompson J.  ...  3.50   1.30  3.73
# 1       Hard      1st Round        3        Mahut N.  ...  2.50   1.53  2.52
# 2       Hard      1st Round        3       Ferrer D.  ...  2.00   1.80  2.10
# 3       Hard      1st Round        3       Edmund K.  ...  1.40   3.00  1.42
# 4       Hard      1st Round        3     Dimitrov G.  ...  1.40   3.00  1.41
# 5       Hard      1st Round        3    Donaldson J.  ...  1.50   2.62  1.51
# 6       Hard      1st Round        3        Groth S.  ...  2.25   1.62  2.34
# 7       Hard      1st Round        3      Pouille L.  ...  1.91   1.91  1.93
# 8       Hard      1st Round        3      Troicki V.  ...  2.50   1.50  2.62
# 9       Hard      1st Round        3  Schwartzman D.  ...  2.20   1.67  2.20
# 10      Hard      1st Round        3       Zverev M.  ...  2.62   1.50  2.80
# 11      Hard      1st Round        3        Nadal R.  ...  1.17   5.00  1.15
# 12      Hard      2nd Round        3    Nishikori K.  ...  1.12   6.00  1.12
# 13      Hard      2nd Round        3     Thompson J.  ...  4.50   1.20  4.93
# 14      Hard      2nd Round        3       Edmund K.  ...  2.50   1.53  2.60
# 15      Hard      2nd Round        3     Wawrinka S.  ...  3.50   1.30  3.60
# 16      Hard      2nd Round        3     Dimitrov G.  ...  4.00   1.25  5.00
# 17      Hard      2nd Round        3        Thiem D.  ...  4.33   1.22  4.97
# 18      Hard      2nd Round        3       Raonic M.  ...  5.50   1.14  6.44
# 19      Hard      2nd Round        3        Nadal R.  ...  6.50   1.11  6.76
# 20      Hard  Quarterfinals        3     Wawrinka S.  ...  1.30   3.40  1.33
# 21      Hard  Quarterfinals        3    Nishikori K.  ...  1.17   5.00  1.15
# 22      Hard  Quarterfinals        3     Dimitrov G.  ...  2.10   1.73  2.36
# 23      Hard  Quarterfinals        3       Raonic M.  ...  1.53   2.50  1.70
# 24      Hard     Semifinals        3    Nishikori K.  ...  2.25   1.62  2.52
# 25      Hard     Semifinals        3     Dimitrov G.  ...  1.44   2.75  1.46
# 26      Hard      The Final        3     Dimitrov G.  ...  2.75   1.44  2.74
# 27      Hard      1st Round        3       Darcis S.  ...  1.22   4.33  1.26
# 28      Hard      1st Round        3         Sela D.  ...  1.73   2.00  1.81
# 29      Hard      1st Round        3     Medvedev D.  ...  1.18   4.33  1.25
# ...      ...            ...      ...             ...  ...   ...    ...   ...
# 2607    Hard      3rd Round        3        Cilic M.  ...   NaN    NaN  2.90
# 2608    Hard      3rd Round        3    Khachanov K.  ...   NaN    NaN  2.63
# 2609    Hard      3rd Round        3     Djokovic N.  ...   NaN    NaN  1.04
# 2610    Hard      3rd Round        3       Zverev A.  ...   NaN    NaN  1.29
# 2611    Hard      3rd Round        3         Sock J.  ...   NaN    NaN  1.40
# 2612    Hard      3rd Round        3        Thiem D.  ...   NaN    NaN  1.83
# 2613    Hard      3rd Round        3      Federer R.  ...   NaN    NaN  6.61
# 2614    Hard      3rd Round        3    Nishikori K.  ...   NaN    NaN  2.24
# 2615    Hard  Quarterfinals        3    Khachanov K.  ...   NaN    NaN  2.88
# 2616    Hard  Quarterfinals        3        Thiem D.  ...   NaN    NaN  1.29
# 2617    Hard  Quarterfinals        3     Djokovic N.  ...   NaN    NaN  1.19
# 2618    Hard  Quarterfinals        3      Federer R.  ...   NaN    NaN  1.47
# 2619    Hard     Semifinals        3    Khachanov K.  ...   NaN    NaN  1.98
# 2620    Hard     Semifinals        3     Djokovic N.  ...   NaN    NaN  3.12
# 2621    Hard      The Final        3    Khachanov K.  ...   NaN    NaN  1.19
# 2622    Hard    Round Robin        3     Anderson K.  ...   NaN    NaN  1.81
# 2623    Hard    Round Robin        3    Nishikori K.  ...   NaN    NaN  1.29
# 2624    Hard    Round Robin        3       Zverev A.  ...   NaN    NaN  2.06
# 2625    Hard    Round Robin        3     Djokovic N.  ...   NaN    NaN  1.12
# 2626    Hard    Round Robin        3     Anderson K.  ...   NaN    NaN  1.73
# 2627    Hard    Round Robin        3      Federer R.  ...   NaN    NaN  3.42
# 2628    Hard    Round Robin        3     Djokovic N.  ...   NaN    NaN  1.18
# 2629    Hard    Round Robin        3        Cilic M.  ...   NaN    NaN  1.49
# 2630    Hard    Round Robin        3        Thiem D.  ...   NaN    NaN  1.57
# 2631    Hard    Round Robin        3      Federer R.  ...   NaN    NaN  1.37
# 2632    Hard    Round Robin        3       Zverev A.  ...   NaN    NaN  3.22
# 2633    Hard    Round Robin        3     Djokovic N.  ...   NaN    NaN  1.20
# 2634    Hard     Semifinals        3       Zverev A.  ...   NaN    NaN  1.41
# 2635    Hard     Semifinals        3     Djokovic N.  ...   NaN    NaN  7.72
# 2636    Hard      The Final        3       Zverev A.  ...   NaN    NaN  1.16
#
#        PSP2  MaxP1  MaxP2  AvgP1  AvgP2  PtsDelta  IntervalDelta
# 0      1.31   3.90   1.33   3.50   1.29    -317.0           -1.0
# 1      1.58   2.55   1.59   2.43   1.54    -248.0           -1.0
# 2      1.81   2.15   1.82   2.01   1.77     320.0            1.0
# 3      3.09   1.42   3.25   1.37   3.01     558.0            1.0
# 4      3.13   1.46   3.13   1.41   2.85     715.0            2.0
# 5      2.74   1.51   2.75   1.47   2.64     685.0            2.0
# 6      1.66   2.40   1.66   2.27   1.61    -378.0           -1.0
# 7      1.95   1.93   2.00   1.83   1.94     571.0            2.0
# 8      1.54   2.85   1.54   2.57   1.49    -781.0           -2.0
# 9      1.74   2.30   1.74   2.18   1.66    -491.0           -1.0
# 10     1.49   2.80   1.50   2.70   1.45    -742.0           -2.0
# 11     6.34   1.20   6.34   1.14   5.34    2540.0            5.0
# 12     7.58   1.14   7.58   1.11   6.37    4335.0            5.0
# 13     1.22   5.00   1.23   4.46   1.20   -1096.0           -3.0
# 14     1.56   2.75   1.57   2.51   1.51   -1155.0           -3.0
# 15     1.34   3.60   1.35   3.39   1.31   -3930.0           -5.0
# 16     1.21   5.00   1.25   4.39   1.20    -933.0           -3.0
# 17     1.22   4.97   1.25   4.40   1.20   -3095.0           -5.0
# 18     1.15   6.44   1.17   5.66   1.13   -4586.0           -5.0
# 19     1.14   6.80   1.14   6.16   1.11   -2426.0           -5.0
# 20     3.77   1.33   3.80   1.30   3.48    4314.0            5.0
# 21     6.73   1.20   6.73   1.15   5.52    4216.0            5.0
# 22     1.68   2.36   1.78   2.16   1.68    1380.0            3.0
# 23     2.31   1.70   2.60   1.56   2.40   -2150.0           -5.0
# 24     1.61   2.60   1.75   2.30   1.61     410.0            1.0
# 25     2.99   1.50   3.00   1.45   2.70    3415.0            5.0
# 26     1.53   2.85   1.55   2.65   1.48   -2870.0           -5.0
# 27     4.25   1.26   4.33   1.23   4.06     514.0            1.0
# 28     2.10   1.83   2.10   1.77   2.02      83.0            1.0
# 29     4.36   1.25   4.70   1.21   4.30     -63.0           -1.0
# ...     ...    ...    ...    ...    ...       ...            ...
# 2607   1.48   2.90   1.50   2.75   1.46    -715.0           -2.0
# 2608   1.56   2.70   1.57   2.56   1.53    1580.0            4.0
# 2609  16.78   1.06  19.50   1.03  13.44    6505.0            5.0
# 2610   4.05   1.31   4.18   1.27   3.84    3280.0            5.0
# 2611   3.29   1.41   3.35   1.36   3.19     837.0            2.0
# 2612   2.11   1.86   2.15   1.80   2.03    1365.0            3.0
# 2613   1.15   7.25   1.15   6.00   1.13   -3945.0           -5.0
# 2614   1.75   2.25   1.76   2.14   1.72    1020.0            3.0
# 2615   1.49   2.95   1.49   2.80   1.45   -3270.0           -5.0
# 2616   4.05   1.45   4.05   1.31   3.55    2065.0            5.0
# 2617   5.61   1.19   6.00   1.15   5.56    3395.0            5.0
# 2618   2.93   1.50   2.93   1.46   2.79    3050.0            5.0
# 2619   1.94   2.03   2.00   1.92   1.91   -1980.0           -4.0
# 2620   1.43   3.25   1.47   3.02   1.40   -1185.0           -3.0
# 2621   5.50   1.25   5.50   1.18   5.04    5600.0            5.0
# 2622   2.12   1.90   2.12   1.80   2.03     415.0            1.0
# 2623   4.05   1.30   4.20   1.26   3.97    2630.0            5.0
# 2624   1.85   2.13   1.87   2.04   1.80   -1035.0           -3.0
# 2625   7.50   1.13   7.50   1.11   6.92    4890.0            5.0
# 2626   2.24   1.74   2.35   1.66   2.23    -920.0           -3.0
# 2627   1.37   3.65   1.40   3.28   1.35   -2125.0           -5.0
# 2628   5.73   1.20   6.00   1.16   5.32    2960.0            5.0
# 2629   2.82   1.50   2.95   1.47   2.74     895.0            2.0
# 2630   2.57   1.57   2.74   1.52   2.59    -505.0           -1.0
# 2631   3.38   1.44   3.40   1.38   3.12    1710.0            4.0
# 2632   1.40   3.40   1.44   3.14   1.38   -1930.0           -4.0
# 2633   5.23   1.22   6.03   1.17   5.14    3995.0            5.0
# 2634   3.24   1.45   3.40   1.38   3.14     935.0            3.0
# 2635   1.12   7.72   1.15   6.52   1.12   -3735.0           -5.0
# 2636   6.36   1.22   6.36   1.15   5.69    2960.0            5.0
#
# [16278 rows x 78 columns]

# %%
# get birthday from age and and date 

def get_wbday(info):
    try: 
        age = info['winner_age']
        year = info['tourney_date']
        return year - relativedelta(years=int(age), days=int(((age-int(age))*365.24)))
    except ValueError as e: return np.nan

def get_lbday(info):
    try: 
        age = info['loser_age']
        year = info['tourney_date']
        return year - relativedelta(years=int(age), days=int(((age-int(age))*365.24)))
    except ValueError as e: return np.nan

atp['winner_birthday'] = atp.apply(get_wbday, axis=1)
atp['loser_birthday'] = atp.apply(get_lbday, axis=1)

# %%
atp1 = pd.concat([atp.winner_id,atp.winner_birthday], axis=1).rename(columns={'winner_id':'id', 'winner_birthday':'birthday'})

atp2 = pd.concat([atp.loser_id,atp.loser_birthday], axis=1).rename(columns={'loser_id':'id', 'loser_birthday':'birthday'})

players_only = atp1.append(atp2)

players_only.drop_duplicates(inplace=True, subset='id') #just player id and birthdayd extracted from atp match data


print(len(players), len(players_only))
# Out:
# 53319 2152

# %%
def calculate_age(born, today):
    try:
        delta = relativedelta(today, born)
        return delta.years + delta.months/12
    except: return np.nan
#     return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

players_only.head()
# Out:
#          id   birthday
# 0  102179.0 1973-02-24
# 1  103602.0 1980-07-29
# 2  103387.0 1979-06-15
# 3  101733.0 1970-04-14
# 4  101727.0 1970-04-04

# %%
players_ = pd.merge(players_only, players, on='id') #addbirthday to atp players df. - all atp data

# %%
len(players_)
len(df)
# Out:
# 16278

# %%
players_['initial'] = players_.first_name.str[0]

# %%
_wnames = players_[['surname','initial', 'id','birthday','country',]].rename(columns={'surname':'winner_surname','initial':'winner_initial','id':'winner_id', 'birthday': 'winner_birthday', 'country':'winner_country'})
_lnames = players_[['surname','initial', 'id','birthday','country',]].rename(columns={'surname':'loser_surname','initial':'loser_initial','id':'loser_id', 'birthday': 'loser_birthday', 'country':'loser_country'})

# %%
df = pd.merge(df, _wnames, how='inner', on=['winner_surname', 'winner_initial'], indicator='indicator_column')
df.winner_birthday.apply(pd.to_datetime)
df = pd.merge(df, _lnames, how='inner', on=['loser_surname', 'loser_initial'], indicator='indicator_column_loser_merge')

# %%
df.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
#        'Lsets', 'Comment', 'B365W', 'B365L', 'EXW', 'EXL', 'LBW', 'LBL', 'PSW',
#        'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL', 'SJW', 'SJL', 'loser_surname',
#        'winner_surname', 'winner_initial', 'loser_initial', 'P1', 'P2',
#        'P1Rank', 'P2Rank', 'P1Pts', 'P2Pts', 'P11', 'P21', 'P12', 'P22', 'P13',
#        'P23', 'P14', 'P24', 'P15', 'P25', 'P1sets', 'P2sets', 'B365P1',
#        'B365P2', 'EXP1', 'EXP2', 'P2BP1', 'P2BP2', 'PSP1', 'PSP2', 'MaxP1',
#        'MaxP2', 'AvgP1', 'AvgP2', 'PtsDelta', 'IntervalDelta', 'winner_id',
#        'winner_birthday', 'winner_country', 'indicator_column', 'loser_id',
#        'loser_birthday', 'loser_country', 'indicator_column_loser_merge'],
#       dtype='object')

# %%
all_player_names = set(df.Winner) and set(df.Loser)
df.columns
# Out:
# Index(['ATP', 'Location', 'Tournament', 'Date', 'Series', 'Court', 'Surface',
#        'Round', 'Best of', 'Winner', 'Loser', 'WRank', 'LRank', 'WPts', 'LPts',
#        'W1', 'L1', 'W2', 'L2', 'W3', 'L3', 'W4', 'L4', 'W5', 'L5', 'Wsets',
#        'Lsets', 'Comment', 'B365W', 'B365L', 'EXW', 'EXL', 'LBW', 'LBL', 'PSW',
#        'PSL', 'MaxW', 'MaxL', 'AvgW', 'AvgL', 'SJW', 'SJL', 'loser_surname',
#        'winner_surname', 'winner_initial', 'loser_initial', 'P1', 'P2',
#        'P1Rank', 'P2Rank', 'P1Pts', 'P2Pts', 'P11', 'P21', 'P12', 'P22', 'P13',
#        'P23', 'P14', 'P24', 'P15', 'P25', 'P1sets', 'P2sets', 'B365P1',
#        'B365P2', 'EXP1', 'EXP2', 'P2BP1', 'P2BP2', 'PSP1', 'PSP2', 'MaxP1',
#        'MaxP2', 'AvgP1', 'AvgP2', 'PtsDelta', 'IntervalDelta', 'winner_id',
#        'winner_birthday', 'winner_country', 'indicator_column', 'loser_id',
#        'loser_birthday', 'loser_country', 'indicator_column_loser_merge'],
#       dtype='object')

# %%
df['winner_age'] = df.apply(lambda row : calculate_age(row['winner_birthday'], row['Date']), axis=1)
df['loser_age'] = df.apply(lambda row : calculate_age(row['loser_birthday'], row['Date']), axis=1)
sort_by_player(df, 'P1Age', 'P2Age', 'winner_age', 'loser_age', sort_list)

# %%
df[['Winner', 'winner_age', 'Date', 'winner_birthday']].head()
# Out:
#            Winner  winner_age       Date winner_birthday
# 0     Thompson J.   22.666667 2017-01-01      1994-04-21
# 1       Ferrer D.   33.000000 2015-04-23      1982-04-03
# 2     Dimitrov G.   22.083333 2013-07-08      1991-05-16
# 3  Schwartzman D.   23.000000 2015-08-31      1992-08-17
# 4     Verdasco F.   33.666667 2017-07-18      1983-11-16

# %%
players_[players_.id==102928.0]
# Out:
#            id   birthday first_name surname hand      points country initial
# 500  102928.0 1977-02-03   Hee Seok   Chung    R  19770129.0     KOR       H

# %%
df['P1Result'] = pd.get_dummies(df.P1 == df.Winner, drop_first=True)

df.to_csv('data.csv', index=True, index_label='index')

# %%
train_on = [ 'PtsDelta', 'IntervalDelta' , 'P1Age', 'P2Age', 'P1Result']


# 'PtsDelta',IntervalDelta',

# %%
model_data = df[train_on][df.Date < datetime.datetime(2016,12,31)].copy()
model_data = model_data.dropna()

# %%
X_train, X_test, y_train, y_test = train_test_split(model_data.drop('P1Result', axis=1),model_data['P1Result'], test_size=0.1)

# %%
logmodel = LogisticRegression(solver= 'liblinear', fit_intercept=True)
logmodel.fit(X_train,y_train)
predictions = logmodel.predict(X_test)

# %%
print(classification_report(y_test,predictions))
print(balanced_accuracy_score(y_test,predictions))
print(log_loss(y_test,logmodel.predict_proba(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.65      0.66       439
#            1       0.64      0.66      0.65       412
#
#    micro avg       0.66      0.66      0.66       851
#    macro avg       0.66      0.66      0.66       851
# weighted avg       0.66      0.66      0.66       851
#
# 0.6557627662162462
# 0.6152878133761522

# %%
probs = logmodel.predict_proba(model_data.drop('P1Result', axis=1).iloc[0].values.reshape(1, -1))
np.flip(probs) # P1 Win / P2 Win probs
# Out:
# array([[0.15548887, 0.84451113]])

# %%
probs_odds = 1/probs
np.flip(probs)
# Out:
# array([[0.15548887, 0.84451113]])

# %%
def expected_return(probs,odds):
    er_0 = probs[0,0]*(odds[0]-1) - probs[0,1]
    er_1 = probs[0,1]*(odds[1]-1) - probs[0,0]
    return (er_0, er_1)


odds = df.iloc[0][['B365P1','B365P2']]


#Kelly stake 

def kelly_ratio(er,odds):
    kr_0, kr_1 = er/(odds-1)
    return (max(0,kr_0), max(0,kr_1))

print(expected_return(np.flip(probs), odds ))
print(kelly_ratio(expected_return(np.flip(probs), odds ), odds))

# %%
test_data = df[df.Date > datetime.datetime(2016,12,31)].copy()

# %%
test_data['Probs'] = logmodel.predict_proba(test_data[[ 'PtsDelta', 'IntervalDelta' , 'P1Age', 'P2Age']].values)

# %%
test_data[[ 'PtsDelta', 'IntervalDelta' , 'P1Age', 'P2Age']].values

# %%
y_test.mean()

# %%
2.718281828**(logmodel.intercept_)/(1+2.718281828**(logmodel.intercept_))
